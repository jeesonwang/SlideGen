# %%
import sys

sys.path.append('/Users/wjs/work/pyproj/SlideGen/slidegen')
sys.path.append('/Users/wjs/work/pyproj/SlideGen')
import pptx
from pptx.oxml import parse_xml

presentation = pptx.Presentation("data/紫藤萝瀑布教学课件.pptx")
source_slide = presentation.slides[7]

# cl = CatalogPage._get_catalog_items(source_slide)

# %%
from pptx.shapes.autoshape import Shape

shape_index = 2
source_shape: Shape = cl[shape_index].text_shape["shape"]
source_number_shape: Shape = cl[shape_index].number_shape["shape"]

template = cl[0]
template_shape: Shape = template.text_shape["shape"]
temp_xml = template_shape.text_frame.paragraphs[0]._element.xml

# print(temp_xml)
# print("--------------------------------")
# print(source_shape.text_frame.paragraphs[0]._element.xml)

# par = source_shape.text_frame.paragraphs[0]
# par._element.getparent().remove(par._element)
# etree.fromstring(temp_xml)

# %%
print(source_number_shape.text)
for par in source_shape.text_frame.paragraphs:
    print(par.text)
    print(par._element.xml)
    print("--------------------------------")

# 通过xml添加shape
# Out:
# 03
# 课文解析
# <a:p xmlns:a="http://schemas.openxmlformats.org/drawingml/2006/main" xmlns:r="http://schemas.openxmlformats.org/officeDocument/2006/relationships" xmlns:p="http://schemas.openxmlformats.org/presentationml/2006/main">
#   <a:pPr algn="l"/>
#   <a:r>
#     <a:rPr lang="zh-CN" altLang="en-US" sz="2200" dirty="0">
#       <a:solidFill>
#         <a:schemeClr val="bg2">
#           <a:lumMod val="25000"/>
#         </a:schemeClr>
#       </a:solidFill>
#       <a:uFillTx/>
#       <a:latin typeface="+mj-ea"/>
#       <a:ea typeface="+mj-ea"/>
#       <a:cs typeface="MiSans Normal" panose="00000500000000000000" charset="-122"/>
#     </a:rPr>
#     <a:t>课文解析</a:t>
#   </a:r>
# </a:p>
#
# --------------------------------

# %%
new_slide = presentation.slides.add_slide(source_slide.slide_layout)

# %%
shape_xml = """<p:sp xmlns:p="http://schemas.openxmlformats.org/presentationml/2006/main" xmlns:a="http://schemas.openxmlformats.org/drawingml/2006/main" xmlns:r="http://schemas.openxmlformats.org/officeDocument/2006/relationships">
  <p:nvSpPr>
    <p:cNvPr id="24" name="椭圆 23"/>
    <p:cNvSpPr/>
    <p:nvPr>
    </p:nvPr>
  </p:nvSpPr>
  <p:spPr>
    <a:xfrm>
      <a:off x="2919413" y="1443355"/>
      <a:ext cx="1890270" cy="1890270"/>
    </a:xfrm>
    <a:prstGeom prst="ellipse">
      <a:avLst/>
    </a:prstGeom>
    <a:solidFill>
      <a:schemeClr val="accent1">
        <a:alpha val="15000"/>
      </a:schemeClr>
    </a:solidFill>
    <a:ln w="38100">
      <a:noFill/>
    </a:ln>
  </p:spPr>
  <p:style>
    <a:lnRef idx="2">
      <a:schemeClr val="accent1">
        <a:lumMod val="75000"/>
      </a:schemeClr>
    </a:lnRef>
    <a:fillRef idx="1">
      <a:schemeClr val="accent1"/>
    </a:fillRef>
    <a:effectRef idx="0">
      <a:srgbClr val="FFFFFF"/>
    </a:effectRef>
    <a:fontRef idx="minor">
      <a:schemeClr val="lt1"/>
    </a:fontRef>
  </p:style>
  <p:txBody>
    <a:bodyPr rtlCol="0" anchor="ctr"/>
    <a:lstStyle/>
    <a:p>
      <a:pPr algn="ctr"/>
      <a:endParaRPr lang="zh-CN" altLang="en-US"/>
    </a:p>
  </p:txBody>
</p:sp>
"""

new_slide.shapes._spTree.insert_element_before(parse_xml(shape_xml))
# Out:
# <CT_Shape '<p:sp>' at 0x131ee45a0>

# %%
presentation.save("test_2_1.pptx")

# %%
parse_xml()
# Out:
# <CT_TextParagraph '<a:p>' at 0x135b640a0>
